# %%
import requests
import bs4 as bs
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
# userName = input("Enter valid github user name")
userName = "adithya-s-k"

HEADERS = ({'User-Agent':
			'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
			'Accept-Language': 'en-US, en;q=0.5'})

following = "https://github.com/"+str(userName)+"?tab=following"

follower = "https://github.com/"+str(userName)+"?tab=followers"

# HTTP Request
following_request = requests.get(following, headers=HEADERS)
follower_request = requests.get(follower, headers=HEADERS)

# Soup Object containing all data
following_page = bs(following_request.content, "lxml")
follower_page = bs(follower_request.content, "lxml")


following_name = following_page.find_all("span",{"class": "f4 Link--primary"})
following_username = following_page.find_all("span",{"class": "Link--secondary"})

print("Please who you are following\n\n")

for (name,username) in zip(following_name,following_username):
    print("Name :",name.string," || UserName :",username.string)

follower_name = follower_page.find_all("span",{"class": "f4 Link--primary"})
follower_username = follower_page.find_all("span",{"class": "Link--secondary"})

print("\n\nPlease who follow you\n\n")

for (name,username) in zip(follower_name,follower_username):
    print("Name :",name.string," || UserName :",username.string)
# Out:
# Please who you are following
#
#
# Name : Nandish N S  || UserName : Nandish2021
# Name : None  || UserName : Aavish-Gilbert-J
# Name : Sathvik Murthy  || UserName : sathvikmurthy
# Name : Gautham Atreyas  || UserName : Shogunkayo
# Name : Abhiraj  || UserName : abhiraj2
# Name : Abhishek Honnapure  || UserName : its-abhishek
# Name : None  || UserName : Achala-Nayak
# Name : None  || UserName : dhritikrishnan
# Name : raunak kodwani  || UserName : kanuar
# Name : AvniG  || UserName : saikidou01
# Name : Ishita Bharadwaj  || UserName : IshitaBharadwaj
# Name : None  || UserName : SowmeshSharma0411
# Name : Ghanashyam Bhat  || UserName : Ghanashyam-Bhat
# Name : None  || UserName : Ninja2k3
# Name : Kishan Balaji  || UserName : Kishan-balaji
# Name : None  || UserName : aishwarya-debug
# Name : None  || UserName : Sakthe-Balan
# Name : Amish Gupta  || UserName : amishgupta2909
# Name : Akshatha MK  || UserName : Akshathamk-123
# Name : Akash Kamalesh  || UserName : asphytheghoul
# Name : Amulya Marali  || UserName : amulyamarali
# Name : None  || UserName : Anushkaghei
# Name : Sarthak S Kumar  || UserName : SarthakSKumar
# Name : Srividya Prasad  || UserName : srividyaprasad
# Name : Shamanth K M  || UserName : Shamanthkolegodu
# Name : Arvind Krishna  || UserName : ArvindAROO
# Name : B Monish Moger  || UserName : senju-hashirama
# Name : Anirudh Revanur  || UserName : AnirudhRevanur
# Name : None  || UserName : adithyag17
# Name : None  || UserName : aayushsenapati
# Name : Aaryan H Badyal  || UserName : aaryanhb
#
#
# Please who follow you
#
#
# Name : None  || UserName : Aavish-Gilbert-J
# Name : Nandish N S  || UserName : Nandish2021
# Name : Abhiraj  || UserName : abhiraj2
# Name : Gautham Atreyas  || UserName : Shogunkayo
# Name : Prathik Umbarji  || UserName : PrathikUmbarji
# Name : None  || UserName : AishwaryaLPatil
# Name : None  || UserName : Achala-Nayak
# Name : Abhishek Honnapure  || UserName : its-abhishek
# Name : None  || UserName : yadavabhinav559
# Name : raunak kodwani  || UserName : kanuar
# Name : None  || UserName : dhritikrishnan
# Name : Ishita Bharadwaj  || UserName : IshitaBharadwaj
# Name : None  || UserName : Ninja2k3
# Name : Kishan Balaji  || UserName : Kishan-balaji
# Name : None  || UserName : aishwarya-debug
# Name : None  || UserName : Sakthe-Balan
# Name : Amish Gupta  || UserName : amishgupta2909
# Name : Akash Kamalesh  || UserName : asphytheghoul
# Name : Akshatha MK  || UserName : Akshathamk-123
# Name : Amulya Marali  || UserName : amulyamarali
# Name : None  || UserName : Anushkaghei
# Name : B Monish Moger  || UserName : senju-hashirama
# Name : Sarthak S Kumar  || UserName : SarthakSKumar
# Name : Srividya Prasad  || UserName : srividyaprasad
# Name : Shamanth K M  || UserName : Shamanthkolegodu
# Name : Arvind Krishna  || UserName : ArvindAROO
# Name : AvniG  || UserName : saikidou01
# Name : Anirudh Revanur  || UserName : AnirudhRevanur
# Name : None  || UserName : adithyag17
# Name : None  || UserName : aayushsenapati
# Name : Aaryan H Badyal  || UserName : aaryanhb
