# %%
import requests
import bs4 as bs
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
userName = input("Enter valid github user name")

HEADERS = ({'User-Agent':
			'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
			'Accept-Language': 'en-US, en;q=0.5'})

following = "https://github.com/"+str(userName)+"?tab=following"

follower = "https://github.com/"+str(userName)+"?tab=followers"

follower_list = []
following_list = []

follower_set = set()
following_set = set()

# HTTP Request
following_request = requests.get(following, headers=HEADERS)
follower_request = requests.get(follower, headers=HEADERS)

# Soup Object containing all data
following_page = bs(following_request.content, "lxml")
follower_page = bs(follower_request.content, "lxml")

following_name = following_page.find_all("span",{"class": "f4 Link--primary"})
following_username = following_page.find_all("span",{"class": "Link--secondary"})

print("People who you are following\n")

for (name,username) in zip(following_name,following_username):
    following_list.append([name.string,username.string])
    follower_set.add(username.string)

following_df = pd.DataFrame(following_list, columns=['Following Name', 'Following Username'])
display(following_df)

follower_name = follower_page.find_all("span",{"class": "f4 Link--primary"})
follower_username = follower_page.find_all("span",{"class": "Link--secondary"})

print("\n\nPeople who follow you\n")

for (name,username) in zip(follower_name,follower_username):
	follower_list.append([name.string,username.string])
	following_set.add(username.string)

follower_df = pd.DataFrame(follower_list, columns=['Name', 'username'])
display(follower_df)

print("\nPeople the user is not following : \n","\n".join(list(following_set - follower_set)))
print("\nPeople who are not following the user : \n","\n".join(list(follower_set - following_set)))
print("\nBoth following and follower\n","\n".join(list(follower_set.intersection(following_set))))
# Out:
# People who you are following
#         Following Name Following Username
# 0       Arvind Krishna         ArvindAROO
# 1               Shunya         Shunya-PES
# 2     Tushar Kesarwani    TusharKesarwani
# 3      Aniruddha Bagal     aniruddhabagal
# 4   Abhishek Honnapure       its-abhishek
# 5                 None        rajathcodes
# 6                 None        MaNameEJeff
# 7          Bharath Raj        Bharath2584
# 8                 None          Atifbeast
# 9      Srividya Prasad     srividyaprasad
# 10        Manab Biswas           manab-kb
# 11     Prathima Kadari   prathimacode-hub
# 12        Arnab Biswas    ArnabBiswas2303
# 13         Adithya S K        adithya-s-k
# 14         Souvik Ojha         techsouvik
# 15        Neeraj Singh          karma9874
# 16         Sriniketh J           srini047
# 17       Bhaswati Roy         BhaswatiRoy
# 18         Tanisha Rai       tanisharai21
# 19        Aditya Bisoi        adityabisoi
# People who follow you
#                    Name            username
# 0           Nandish N S         Nandish2021
# 1                  None           YessiRNTH
# 2        Arvind Krishna          ArvindAROO
# 3      Prakash Naikwadi    prakash-naikwadi
# 4                  None        supramprasad
# 5         Ranjith Kumar  shettyranjithkumar
# 6                JCSIVO              JCSIVO
# 7       MD HASNAIN IMAM       Mdhasnainimam
# 8                  None      Vandanaprabhu7
# 9       Aniruddha Bagal      aniruddhabagal
# 10         Satyam Kumar       satyamksharma
# 11                 None          tejasantil
# 12          Harshit Raj       iamrajharshit
# 13                vivek             Vive007
# 14                 None          1729-Vivek
# 15                 None        Gauravag6432
# 16          Karthik Ram            cypherbb
# 17       Vanishka Gupta           vanishkag
# 18           Esha patil           eshapatil
# 19                 None           Pannagahs
# 20       Sourabh Shenoy     sourabhshenoy04
# 21                 None       KeerthanaNP15
# 22              Suhas K        An-4lchemist
# 23  Brijwin Balakrishna  BrijwinBalakrishna
# 24            Vishwas M         Vishwas1451
# 25                 None             Prad143
# 26                 None     chantelledmonte
# 27                 None      SharanShetty11
# 28                 None             sujan03
# 29         Thejalakshmi      Thejalakshmi28
# 30                 None    hdkiranbharadwaj
# 31                 None       alden-olivero
# 32         Pranav Desai         daftylooper
# 33                 None         rajathcodes
# 34             Vishal S          VishalS-HK
# 35         Sarang Kumar         SarangKumar
# 36        Yashwanth Sai     theyashwanthsai
# 37                 None       scanda-shetty
# 38      Srividya Prasad      srividyaprasad
# 39                 None           Atifbeast
# 40                 None          Manoj-2702
# 41           Aditya A S            ad1tya24
# 42         Manab Biswas            manab-kb
# 43         vivekweb2013        vivekweb2013
# 44          Adithya S K         adithya-s-k
# 45   Ashish Vishwakarma          thisashish
# 46                 None           kunal-bmd
# 47                 None        Dharshan1405
# 48   Abhishek Honnapure        its-abhishek
# 49              Vineeth            vinrusty
# People the user is not following :
#  thisashish
# Pannagahs
# iamrajharshit
# SarangKumar
# hdkiranbharadwaj
# alden-olivero
# cypherbb
# Gauravag6432
# Prad143
# daftylooper
# JCSIVO
# SharanShetty11
# theyashwanthsai
# Dharshan1405
# BrijwinBalakrishna
# Nandish2021
# KeerthanaNP15
# YessiRNTH
# supramprasad
# vanishkag
# sourabhshenoy04
# satyamksharma
# ad1tya24
# vivekweb2013
# kunal-bmd
# Manoj-2702
# prakash-naikwadi
# eshapatil
# chantelledmonte
# sujan03
# Vive007
# tejasantil
# Thejalakshmi28
# 1729-Vivek
# vinrusty
# Vandanaprabhu7
# VishalS-HK
# Vishwas1451
# scanda-shetty
# Mdhasnainimam
# An-4lchemist
# shettyranjithkumar
#
# People who are not following the user :
#  prathimacode-hub
# ArnabBiswas2303
# karma9874
# srini047
# MaNameEJeff
# tanisharai21
# Bharath2584
# TusharKesarwani
# Shunya-PES
# BhaswatiRoy
# techsouvik
# adityabisoi
#
# Both following and follower
#  manab-kb
# ArvindAROO
# rajathcodes
# aniruddhabagal
# adithya-s-k
# its-abhishek
# srividyaprasad
# Atifbeast
